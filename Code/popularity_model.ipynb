# %% [markdown]
# This model uses the popularity attribute as well as the average rating and voter count in the TMDB data to generate popular movies genre wise. The genres are determined using the IMDB data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ast import literal_eval

# %%
movies = pd.read_csv("movies_tmdb.csv")

# %%
movies.sort_values(by='popularity', ascending=False)
# Out:
#        Unnamed: 0  movieId                                            genres  \
# 32753       32753   135887  ['Adventure', 'Animation', 'Children', 'Comedy']
# 35929       35929   143355                ['Action', 'Adventure', 'Fantasy']
# 46747       46747   168366                            ['Fantasy', 'Romance']
# 48325       48325   171763                   ['Action', 'Crime', 'Thriller']
# 25016       25016   115617                 ['Action', 'Animation', 'Comedy']
# ...           ...      ...                                               ...
# 58123       58123   193876                            ['(no genres listed)']
# 58124       58124   193878                                        ['Comedy']
# 58125       58125   193880                                         ['Drama']
# 58126       58126   193882        ['Adventure', 'Drama', 'Horror', 'Sci-Fi']
# 58127       58127   193886                      ['Action', 'Crime', 'Drama']
#
#                                                 overview  popularity  \
# 32753  Minions Stuart, Kevin and Bob are recruited by...  547.488298
# 35929  An Amazon princess comes to the world of Man t...  294.337037
# 46747  A live-action adaptation of Disney's version o...  287.253654
# 48325  After being coerced into working for a crime b...  228.032744
# 25016  The special bond that develops between plus-si...  213.849907
# ...                                                  ...         ...
# 58123                                                NaN         NaN
# 58124                                                NaN         NaN
# 58125                                                NaN         NaN
# 58126                                                NaN         NaN
# 58127                                                NaN         NaN
#
#       release_date                                         tagline  \
# 32753   2015-06-17    Before Gru, they had a history of bad bosses
# 35929   2017-05-30                   Power. Grace. Wisdom. Wonder.
# 46747   2017-03-16                                   Be our guest.
# 48325   2017-06-28               All you need is one killer track.
# 25016   2014-10-24  From the creators of Wreck-it Ralph and Frozen
# ...            ...                                             ...
# 58123          NaN                                             NaN
# 58124          NaN                                             NaN
# 58125          NaN                                             NaN
# 58126          NaN                                             NaN
# 58127          NaN                                             NaN
#
#                       title  vote_average  vote_count
# 32753               Minions           6.4      4729.0
# 35929          Wonder Woman           7.2      5025.0
# 46747  Beauty and the Beast           6.8      5530.0
# 48325           Baby Driver           7.2      2083.0
# 25016            Big Hero 6           7.8      6289.0
# ...                     ...           ...         ...
# 58123                   NaN           NaN         NaN
# 58124                   NaN           NaN         NaN
# 58125                   NaN           NaN         NaN
# 58126                   NaN           NaN         NaN
# 58127                   NaN           NaN         NaN
#
# [58128 rows x 10 columns]

# %% [markdown]
# ## Genres
#
#  'Adventure'<br>
#  'Animation'<br>
#  'Children'<br>
#  'Comedy'<br>
#  'Fantasy'<br>
#  'Romance'<br>
#  'Drama'<br>
#  'Action'<br>
#  'Crime'<br>
#  'Thriller'<br>
#  'Horror'<br>
#  'Mystery'<br>
#  'Sci-Fi'<br>
#  'War'<br>
#  'Musical'<br>
#  'Documentary'<br>
#  'IMAX'<br>
#  'Western'<br>
#  'Film-Noir'<br>
#  '(no genres listed)'<br>

# %%
genres = {'Adventure': 0,
 'Animation': 1,
 'Children': 2,
 'Comedy': 3,
 'Fantasy': 4,
 'Romance': 5,
 'Drama': 6,
 'Action': 7,
 'Crime': 8,
 'Thriller': 9,
 'Horror': 10,
 'Mystery': 11,
 'Sci-Fi': 12,
 'War': 13,
 'Musical': 14,
 'Documentary': 15,
 'IMAX': 16,
 'Western': 17,
 'Film-Noir': 18,
 '(no genres listed)': 19}

# %%
def genre_based_popularity(genre):
    mask = movies.genres.apply(lambda x: genre in x)
    filtered_movie = movies[mask]
    filtered_movie = filtered_movie.sort_values(by='popularity', ascending=False)
    return filtered_movie

# %%
genre_based_popularity('Animation')[['title', 'popularity']].head(25)
# Out:
#                                           title  popularity
# 32753                                   Minions  547.488298
# 25016                                Big Hero 6  213.849907
# 47929  Captain Underpants: The First Epic Movie   88.561239
# 5522                              Spirited Away   41.048867
# 48707                           Despicable Me 3   36.631519
# 45789                            A Silent Voice   34.852055
# 44363                                Your Name.   34.461252
# 50057                           The Emoji Movie   33.694599
# 4793                             Monsters, Inc.   26.419962
# 39518                                  Zootopia   26.024868
# 6275                               Finding Nemo   25.497794
# 21452                           Despicable Me 2   24.823550
# 22453                                    Frozen   24.248243
# 32314                                Inside Out   23.985587
# 589                        Beauty and the Beast   23.433511
# 1997                            The Jungle Book   22.845448
# 15608                             Despicable Me   22.274502
# 8282                            The Incredibles   22.220214
# 25825                    Penguins of Madagascar   22.201607
# 0                                     Toy Story   21.946943
# 360                               The Lion King   21.605761
# 1826                                      Mulan   21.180857
# 50411                            In a Heartbeat   20.821780
# 11645                               Ratatouille   20.508030
# 43194                 Ice Age: Collision Course   20.151037

# %%
genre_based_popularity('Romance')[['title', 'popularity']].head(25)
# Out:
#                                            title  popularity
# 46747                       Beauty and the Beast  287.253654
# 48996                              The Bad Batch   78.807200
# 352                                 Forrest Gump   48.307194
# 2242                           Life Is Beautiful   39.394970
# 45789                             A Silent Voice   34.852055
# 44363                                 Your Name.   34.461252
# 10378                Dilwale Dulhania Le Jayenge   34.457024
# 39487                              Me Before You   34.347590
# 15542                 The Twilight Saga: Eclipse   34.047399
# 28859                       Fifty Shades of Grey   33.068431
# 13221                                   Twilight   31.282029
# 14532                The Twilight Saga: New Moon   30.121292
# 46900                        Fifty Shades Darker   29.130443
# 1663                                     Titanic   26.889070
# 20061  The Twilight Saga: Breaking Dawn - Part 2   26.080995
# 18345  The Twilight Saga: Breaking Dawn - Part 1   25.972500
# 22453                                     Frozen   24.248243
# 589                         Beauty and the Beast   23.433511
# 46727                               The Big Sick   23.424794
# 22895                                  Divergent   21.572585
# 5222                                      Enigma   21.520641
# 1826                                       Mulan   21.180857
# 50411                             In a Heartbeat   20.821780
# 2775                             American Beauty   20.726578
# 20705                        Beautiful Creatures   20.485203

# %%
genre_based_popularity('Action')[['title', 'popularity']].head(25)
# Out:
#                                                    title  popularity
# 35929                                       Wonder Woman  294.337037
# 48325                                        Baby Driver  228.032744
# 25016                                         Big Hero 6  213.849907
# 27573                                           Deadpool  187.860492
# 27578                     Guardians of the Galaxy Vol. 2  185.330992
# 14661                                             Avatar  185.070892
# 24908                                          John Wick  183.870374
# 48999                     War for the Planet of the Apes  146.161786
# 27579                         Captain America: Civil War  145.882135
# 12566                                    The Dark Knight  123.167259
# 537                                         Blade Runner   96.272374
# 18006                                       The Avengers   89.887648
# 47929           Captain Underpants: The First Epic Movie   88.561239
# 24656                                    The Maze Runner   76.937890
# 47501                                    Alien: Covenant   72.884078
# 46852                                 Ghost in the Shell   68.726676
# 47945                               Boyka: Undisputed IV   67.955052
# 2876                                          Fight Club   63.869599
# 27577                                     Thor: Ragnarok   57.283628
# 46690                                              Logan   54.581997
# 24252                            Guardians of the Galaxy   53.291601
# 43424                                      The Last King   50.949523
# 46688                               John Wick: Chapter 2   49.247505
# 47898                            The Fate of the Furious   48.573287
# 6433   Pirates of the Caribbean: The Curse of the Bla...   47.326665

# %% [markdown]
# ## Calculate the weighted rating

# %%
# this is V
vote_counts = movies[movies['vote_count'].notnull()]['vote_count'].astype('int')

# this is R
vote_averages = movies[movies['vote_average'].notnull()]['vote_average'].astype('int')

# this is C
C = vote_averages.mean()
C
# Out:
# 5.246875482178676

# %%
m = vote_counts.quantile(0.95)
m
# Out:
# 434.0

# %%
def weighted_rating(x):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
movies['wr'] = movies.apply(weighted_rating, axis=1)

# %%
movies.head()
# Out:
#    Unnamed: 0  movieId                                             genres  \
# 0           0        1  ['Adventure', 'Animation', 'Children', 'Comedy...
# 1           1        2               ['Adventure', 'Children', 'Fantasy']
# 2           2        3                              ['Comedy', 'Romance']
# 3           3        4                     ['Comedy', 'Drama', 'Romance']
# 4           4        5                                         ['Comedy']
#
#                                             overview  popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...   17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...   11.712900   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495   1995-12-22
# 4  Just when George Banks has recovered from his ...    8.387519   1995-02-10
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  vote_average  vote_count        wr
# 0                    Toy Story           7.7      5415.0  7.517976
# 1                      Jumanji           6.9      2413.0  6.647996
# 2             Grumpier Old Men           6.5        92.0  5.466053
# 3            Waiting to Exhale           6.1        34.0  5.308855
# 4  Father of the Bride Part II           5.7       173.0  5.376020

# %%
def genre_based_popularity_PT(genre):
    mask = movies.genres.apply(lambda x: genre in x)
    filtered_movie = movies[mask]
    filtered_movie = filtered_movie.sort_values(by='wr', ascending=False)
    return filtered_movie

# %%
genre_based_popularity_PT('Animation')[['title', 'wr', 'popularity']].head(10)
# Out:
#                       title        wr  popularity
# 5522          Spirited Away  7.998988   41.048867
# 360           The Lion King  7.799319   21.605761
# 32314            Inside Out  7.739429   23.985587
# 9763   Howl's Moving Castle  7.683828   16.136048
